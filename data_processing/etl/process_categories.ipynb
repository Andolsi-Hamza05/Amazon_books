# %%
# Cell 1 — Start Spark session (do this once)
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Bronze → Silver — Mens Jeans") \
    .master("local[*]") \
    .config("spark.sql.adaptive.enabled", "true") \
    .getOrCreate()

print("Spark is ready!")
spark
